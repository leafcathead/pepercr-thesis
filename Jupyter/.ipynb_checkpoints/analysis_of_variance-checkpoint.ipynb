# %% [markdown]
# # Analysis of Variance

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import f_oneway

# %%
dir_path = "files/Buffalo_Display"

binary_trees_iterative = pd.read_csv(f"{dir_path}/binary-trees-Iterative-COMPLETE-0.csv", index_col=[0])
cacheprof_iterative = pd.read_csv(f"{dir_path}/cacheprof-Iterative-COMPLETE-0.csv", index_col=[0])
fem_iterative = pd.read_csv(f"{dir_path}/fem-Iterative-COMPLETE-0.csv", index_col=[0])
grep_iterative = pd.read_csv(f"{dir_path}/grep-Iterative-COMPLETE-0.csv", index_col=[0])
prolog_iterative = pd.read_csv(f"{dir_path}/prolog-Iterative-COMPLETE-0.csv", index_col=[0])
rsa_iterative = pd.read_csv(f"{dir_path}/rsa-Iterative-COMPLETE-0.csv", index_col=[0])
sorting_iterative = pd.read_csv(f"{dir_path}/sorting-Iterative-COMPLETE-0.csv", index_col=[0])
tables = {"binary_trees": binary_trees_iterative, "cacheprof": cacheprof_iterative, "fem": fem_iterative, "grep": grep_iterative, "prolog": prolog_iterative, "rsa": rsa_iterative, "sorting": sorting_iterative}

# %%
flags = ["-fcall-arity","-fcase-merge","-fcmm-elim-common-blocks","-fcmm-sink","-fcpr-anal","-fcse","-fdicts-cheap","-fdicts-strict","-fdmd-tx-dict-sel","-fdo-eta-reduction","-fdo-lambda-eta-expansion","-feager-blackholing","-fenable-rewrite-rules","-fexcess-precision","-fexpose-all-unfoldings","-ffloat-in","-ffull-laziness","-ffun-to-thunk","-fignore-asserts","-fignore-interface-pragmas","-flate-dmd-anal","-fliberate-case","-fliberate-case-threshold=2000","-floopification","-fmax-inline-alloc-size=128","-fmax-inline-memcpy-insns=32","-fmax-inline-memset-insns=32","-fmax-relevant-binds=6","-fmax-simplifier-iterations=4","-fmax-worker-args=10","-fno-opt-coercion","-fno-pre-inlining","-fno-state-hack","-fomit-interface-pragmas","-fomit-yields","-foptimal-applicative-do","-fpedantic-bottoms","-fregs-graph","-fregs-iterative","-fsimplifier-phases=2","-fsimpl-tick-factor=100","-fspec-constr","-fspec-constr-count=3","-fspec-constr-threshold=2000","-fspecialise","-fcross-module-specialise","-fstatic-argument-transformation","-fstrictness","-fstrictness-before=1","-funbox-small-strict-fields","-funbox-strict-fields","-funfolding-creation-threshold=750","-funfolding-dict-discount=30","-funfolding-fun-discount=60","-funfolding-keeness-factor=1.5","-funfolding-use-threshold=60","-fvectorisation-avoidance","-fvectorise","-fworker-wrapper"]

# %%
## Analysis

# %%
for t_name, t in tables.items():
    flag_matches = []
    for f in flags:
        flag_matches.append([f,t[t["Flags"].apply(lambda x: f in x)]])
    for f in flag_matches:
        print(f[0])
    #f_oneway(*flag_matches["Runtime"])
# Out:
#                                        ID  \
# 2    9ea36d9f-fe6e-4331-ac49-33c7bcb6dc52
# 6    ccecc77c-b295-4555-a36d-e7d7577b2019
# 7    fa9a6919-aebb-4d65-b744-6580b90c50f4
# 13   c07daa6b-8b13-4af4-9eb0-9dd1c1640bdc
# 14   6de95de0-7209-4fd8-b404-9da79fb6748a
# ..                                    ...
# 287  5c5015b7-6216-48d7-866b-083d12caa0c9
# 288  b6965398-afdd-44a0-a956-4446eebc0241
# 291  c24cc909-1812-4edf-b40a-63c42e631c4d
# 294  2906fa5e-c8a0-4554-a229-fbf4fb44afba
# 296  76033463-5bca-421d-9f19-2d54044191c4
#
#                                                  Flags  Mode  Runtime  \
# 2    ['-O0' '-funfolding-dict-discount=30' '-fcpr-a...  norm    6.999
# 6    ['-O0' '-fdicts-strict' '-fexcess-precision' '...  norm    6.949
# 7    ['-O0' '-ffull-laziness' '-fomit-yields'\n '-f...  norm    6.909
# 13   ['-O0' '-fignore-interface-pragmas' '-fcmm-eli...  norm    7.094
# 14   ['-O0' '-fdo-lambda-eta-expansion' '-fignore-a...  norm    6.951
# ..                                                 ...   ...      ...
# 287  ['-O0' '-funbox-strict-fields' '-funfolding-di...  norm    7.148
# 288  ['-O0' '-fcmm-elim-common-blocks' '-ffull-lazi...  norm    7.004
# 291  ['-O0' '-fcmm-sink' '-foptimal-applicative-do'...  norm    7.050
# 294  ['-O0' '-fmax-inline-memcpy-insns=32' '-fcmm-s...  norm    7.091
# 296  ['-O0' '-fmax-inline-memcpy-insns=32' '-fno-op...  norm    7.100
#
#      Elapsed_Time
# 2           6.999
# 6           6.949
# 7           6.909
# 13          7.094
# 14          6.951
# ..            ...
# 287         7.148
# 288         7.004
# 291         7.050
# 294         7.091
# 296         7.100
#
# [130 rows x 5 columns]
#                                        ID  \
# 3    794d7917-c04f-4103-877f-4cc2b08e5b01
# 4    b4ec911d-aba0-451e-8630-1319eeb5e81e
# 6    852574a7-2ca4-44cc-b09d-ad915b090ba4
# 7    3e8481c3-22a0-4720-8bd9-912a913be9e7
# 8    bdc94bea-5a2a-4f3c-a666-df15262d1642
# ..                                    ...
# 291  65360e88-14ac-4d47-90b9-39e2de166fe1
# 292  4297c74d-686c-4f25-a11d-7d775cef235b
# 295  1d92a91b-cf61-491d-94e3-10619d8eddc4
# 299  1f7f60f1-9f47-4a76-9c59-0543e6030b32
# 301  59018623-bf87-492d-8de9-dc5bc0b722d7
#
#                                                  Flags  Mode  Runtime  \
# 3    ['-O0' '-funfolding-use-threshold=60' '-feager...  norm    2.527
# 4    ['-O0' '-fliberate-case-threshold=2000' '-fstr...  norm    2.429
# 6    ['-O0' '-flate-dmd-anal' '-fvectorise' '-fcmm-...  norm    2.427
# 7    ['-O0' '-fvectorisation-avoidance' '-fspeciali...  norm    2.447
# 8    ['-O0' '-fworker-wrapper' '-fworker-wrapper' '...  norm    2.459
# ..                                                 ...   ...      ...
# 291  ['-O0' '-fcpr-anal' '-fmax-inline-memcpy-insns...  norm    2.446
# 292  ['-O0' '-funfolding-dict-discount=30' '-fspeci...  norm    2.467
# 295  ['-O0' '-fworker-wrapper' '-fdicts-cheap' '-fm...  norm    2.570
# 299  ['-O0' '-fcase-merge' '-fmax-inline-alloc-size...  norm    2.454
# 301  ['-O0' '-funfolding-fun-discount=60' '-fcmm-si...  norm    2.473
#
#      Elapsed_Time
# 3           2.527
# 4           2.429
# 6           2.427
# 7           2.447
# 8           2.459
# ..            ...
# 291         2.446
# 292         2.467
# 295         2.570
# 299         2.454
# 301         2.473
#
# [140 rows x 5 columns]
#                                        ID  \
# 5    8bc5ea17-6f0f-4d41-ab67-d0ebb57ab206
# 6    36e6444f-c157-43ac-a2ef-083abda99f66
# 7    5c700d74-6cfa-4d9f-8241-ad6ed07395c0
# 10   2ff337b5-af94-4baf-b2e3-0aa462eeec2f
# 15   cac35657-ea0b-4bb3-8820-38810f39bbda
# ..                                    ...
# 297  d71ad38e-2bc9-451f-bb96-92a7c6f8031f
# 298  5fbe4b98-2dc7-456e-84b5-48e3ffec6c77
# 299  99284bad-b98e-4362-9090-562d1d74a95e
# 300  fc7a4dbc-785d-41d7-b7ef-a2b495f00c49
# 301  78138cb1-dd10-4286-bcb6-1969bc08e1f3
#
#                                                  Flags  Mode  Runtime  \
# 5    ['-O0' '-fstrictness-before=1' '-funfolding-ke...  norm    1.825
# 6    ['-O0' '-feager-blackholing' '-fstatic-argumen...  norm    1.738
# 7    ['-O0' '-fregs-iterative' '-fno-opt-coercion' ...  norm    1.755
# 10   ['-O0' '-feager-blackholing' '-fstatic-argumen...  norm    1.754
# 15   ['-O0' '-feager-blackholing' '-ffull-laziness'...  norm    1.723
# ..                                                 ...   ...      ...
# 297  ['-O0' '-fspec-constr' '-fcall-arity' '-fworke...  norm    1.783
# 298  ['-O0' '-fcall-arity' '-funfolding-fun-discoun...  norm    1.740
# 299  ['-O0' '-foptimal-applicative-do' '-fcmm-elim-...  norm    1.743
# 300  ['-O0' '-fcmm-sink' '-fignore-asserts' '-fmax-...  norm    1.730
# 301  ['-O0' '-fcall-arity' '-flate-dmd-anal' '-fstr...  norm    1.746
#
#      Elapsed_Time
# 5           1.825
# 6           1.738
# 7           1.755
# 10          1.754
# 15          1.723
# ..            ...
# 297         1.783
# 298         1.740
# 299         1.743
# 300         1.730
# 301         1.746
#
# [159 rows x 5 columns]
#                                        ID  \
# 11   8e5facba-4c4e-4634-8038-2e686cacc9e4
# 22   583a34be-1108-4d4d-977d-c5890df1c6c4
# 38   61aa4368-e1d1-47a6-9093-1aa89617cbfb
# 41   5dcc9595-aa7e-4c85-b611-ddcfb7d8f7f2
# 77   1ee9064f-e6fc-4bc8-b12f-041878ef4c7e
# 83   528ceb91-6a8f-4026-9820-6c4ad5be861e
# 88   a586bdde-eb12-4025-aff8-7ca6dc0b7537
# 96   3b59f3ed-eac9-4c76-b913-9ac0e2b4cecc
# 100  8440b5d0-33e3-42ef-bea5-dd722834b5d6
# 128  2e3df418-963d-474d-aee3-e7d5fb4d2911
# 136  e3573049-12b4-461d-8fa3-231cd3f84d0b
# 151  fbff1a0e-88e9-47eb-8e3a-44bb6d9d971a
# 152  7c1a802a-8164-4679-a2c6-bdc427418ae8
# 166  0ab9f5b1-2bd2-4778-b17b-ad5b979acc66
# 175  13a0d199-edc7-40d3-9003-2bd61c69cdbd
# 177  182ecbe1-a021-4c1b-bb47-c21e355a7ee5
# 180  01886d19-aa30-4410-ae29-e4c345a450b6
# 181  63f8b5b7-e208-4770-8c7c-3319491caaaf
# 190  09819157-4b65-4b83-9fde-ca971765f1bd
# 204  fe698307-6554-48da-8bbb-a6ab0a069d65
# 229  b7b90df8-c61e-4751-bbd9-f74c52652576
# 242  8dfb8311-2c6d-48b0-b8c6-90cfe3260eee
# 247  1cc42da0-faa9-4583-a468-50ead008d555
# 265  ed1e422b-1083-40c3-b11b-57018b93715a
#
#                                                  Flags  Mode  Runtime  \
# 11   ['-O0' '-ffun-to-thunk' '-fcmm-sink' '-fvector...  norm    2.560
# 22   ['-O0' '-fdicts-cheap' '-funfolding-use-thresh...  norm    2.576
# 38   ['-O0' '-fpedantic-bottoms' '-fexpose-all-unfo...  norm    2.615
# 41   ['-O0' '-foptimal-applicative-do' '-fcmm-sink'...  norm    2.588
# 77   ['-O0' '-fcmm-sink' '-fstrictness' '-fstrictne...  norm    2.575
# 83   ['-O0' '-fcmm-sink' '-fdicts-strict' '-fignore...  norm    2.601
# 88   ['-O0' '-fcmm-sink' '-fomit-interface-pragmas'...  norm    2.564
# 96   ['-O0' '-fvectorise' '-fmax-simplifier-iterati...  norm    2.574
# 100  ['-O0' '-fworker-wrapper' '-fno-state-hack' '-...  norm    2.585
# 128  ['-O0' '-fexcess-precision' '-fno-pre-inlining...  norm    2.614
# 136  ['-O0' '-fcmm-sink' '-fignore-interface-pragma...  norm    2.588
# 151  ['-O0' '-fsimpl-tick-factor=100' '-fomit-inter...  norm    2.578
# 152  ['-O0' '-fcmm-sink' '-fvectorise' '-fexcess-pr...  norm    2.545
# 166  ['-O0' '-fomit-interface-pragmas' '-fcmm-sink'...  norm    2.582
# 175  ['-O0' '-fcmm-sink' '-fexcess-precision' '-fex...  norm    2.556
# 177  ['-O0' '-fenable-rewrite-rules' '-fcmm-sink' '...  norm    2.581
# 180  ['-O0' '-fno-opt-coercion' '-fno-opt-coercion'...  norm    2.575
# 181  ['-O0' '-fcmm-sink' '-fregs-graph' '-fvectoris...  norm    2.664
# 190  ['-O0' '-fmax-inline-alloc-size=128' '-fcmm-si...  norm    2.628
# 204  ['-O0' '-fcmm-elim-common-blocks' '-funbox-str...  norm    2.645
# 229  ['-O0' '-fcmm-sink' '-fcase-merge' '-fdmd-tx-d...  norm    2.609
# 242  ['-O0' '-fcmm-sink' '-fdmd-tx-dict-sel' '-fcpr...  norm    2.593
# 247  ['-O0' '-fcmm-sink' '-fliberate-case' '-fomit-...  norm    2.607
# 265  ['-O0' '-fspec-constr-count=3' '-fsimpl-tick-f...  norm    2.610
#
#      Elapsed_Time
# 11          2.560
# 22          2.576
# 38          2.615
# 41          2.588
# 77          2.575
# 83          2.601
# 88          2.564
# 96          2.574
# 100         2.585
# 128         2.614
# 136         2.588
# 151         2.578
# 152         2.545
# 166         2.582
# 175         2.556
# 177         2.581
# 180         2.575
# 181         2.664
# 190         2.628
# 204         2.645
# 229         2.609
# 242         2.593
# 247         2.607
# 265         2.610
#                                        ID  \
# 3    87b0bfed-4897-4b23-a59c-3635628db0ee
# 4    cc200c6c-7b8d-470a-a745-9118fc50912a
# 5    f1634f47-05be-4063-858d-6012640840c7
# 6    d94a21bc-7dcd-4607-8447-3f5f270e3998
# 8    74d1420d-67de-419e-b66e-4e14d7884026
# ..                                    ...
# 292  2bfe1585-e402-4758-8655-7993838581f0
# 293  7d7ce471-20e5-494f-8d66-6558ec2e3fbb
# 295  8a39c3aa-eea2-4fda-b6cf-fd72a437163a
# 296  d6a7e7e4-703b-4f80-b3bb-fe0bf36f8cf9
# 299  80eb96fd-bf1e-418f-8368-b19663412e6d
#
#                                                  Flags  Mode  Runtime  \
# 3    ['-O0' '-fstrictness-before=1' '-fomit-interfa...  norm    2.130
# 4    ['-O0' '-fspec-constr-count=3' '-fomit-interfa...  norm    2.216
# 5    ['-O0' '-fmax-simplifier-iterations=4' '-flate...  norm    2.229
# 6    ['-O0' '-flate-dmd-anal' '-fdo-lambda-eta-expa...  norm    2.178
# 8    ['-O0' '-fspecialise' '-funbox-small-strict-fi...  norm    2.145
# ..                                                 ...   ...      ...
# 292  ['-O0' '-flate-dmd-anal' '-fcase-merge' '-fmax...  norm    2.132
# 293  ['-O0' '-floopification' '-funfolding-use-thre...  norm    2.107
# 295  ['-O0' '-fcpr-anal' '-fvectorisation-avoidance...  norm    2.153
# 296  ['-O0' '-floopification' '-fmax-inline-memset-...  norm    2.142
# 299  ['-O0' '-fomit-yields' '-fmax-inline-memcpy-in...  norm    2.108
#
#      Elapsed_Time
# 3           2.130
# 4           2.216
# 5           2.229
# 6           2.178
# 8           2.145
# ..            ...
# 292         2.132
# 293         2.107
# 295         2.153
# 296         2.142
# 299         2.108
#
# [165 rows x 5 columns]
#                                        ID  \
# 5    2c1533a8-0f11-4884-b66b-e79e21b00571
# 7    b5c7a9c3-d157-4ea9-af05-77038a56b4a4
# 8    5e40b08d-0868-4f36-b38c-8bca4cb322e0
# 13   32fa98cf-e409-4f4e-a0a7-7816ba4e4f69
# 14   fb03e057-b220-4c9e-b3a0-0a43103fc1cb
# ..                                    ...
# 286  2ffc6ef7-61a1-49c6-bea6-138caeccb30c
# 291  27a54758-eb62-4a2a-94db-62dae70f4560
# 292  f96f15d1-96bd-4b37-9dc9-ee5b645ab263
# 293  caa341c6-e631-44c1-b352-fc0cc7c29421
# 295  c395be71-5d06-4f0d-8327-dacb93af1493
#
#                                                  Flags  Mode  Runtime  \
# 5    ['-O0' '-ffull-laziness' '-foptimal-applicativ...  norm    2.328
# 7    ['-O0' '-fspec-constr' '-fdmd-tx-dict-sel' '-f...  norm    2.312
# 8    ['-O0' '-fexcess-precision' '-funfolding-creat...  norm    2.290
# 13   ['-O0' '-fspec-constr-threshold=2000' '-funbox...  norm    2.282
# 14   ['-O0' '-fdmd-tx-dict-sel' '-fcse' '-fcmm-elim...  norm    2.321
# ..                                                 ...   ...      ...
# 286  ['-O0' '-fvectorise' '-fcmm-elim-common-blocks...  norm    2.356
# 291  ['-O0' '-fexpose-all-unfoldings' '-fspec-const...  norm    2.394
# 292  ['-O0' '-fcse' '-fvectorise' '-fmax-inline-mem...  norm    2.403
# 293  ['-O0' '-fignore-asserts' '-fenable-rewrite-ru...  norm    2.346
# 295  ['-O0' '-funbox-strict-fields' '-fcmm-sink' '-...  norm    2.368
#
#      Elapsed_Time
# 5           2.328
# 7           2.312
# 8           2.290
# 13          2.282
# 14          2.321
# ..            ...
# 286         2.356
# 291         2.394
# 292         2.403
# 293         2.346
# 295         2.368
#
# [107 rows x 5 columns]
#                                        ID  \
# 5    d9c8b3c1-a1bf-48c5-9288-f43b940690ce
# 6    d1fb0dbc-5ac5-4140-8d37-69e3ab96f9ff
# 8    4e82f293-0f0d-427a-8479-bd1727ea63b7
# 10   6de6c900-cc48-48b4-af2e-4a2e72fd1ae8
# 11   bc8cdc06-689f-47e6-8ff8-ff7542b1be19
# ..                                    ...
# 269  aa020219-9811-48d6-ad4d-5d96faa5072b
# 285  5b1e6dbc-ffb5-4a5c-98ad-8a8e6066cb46
# 291  e5137c89-e306-4d7d-9664-943b30ef24f5
# 294  de9df510-261b-4fa2-926e-8fb31df680e9
# 301  d0561c73-fd04-4e72-a52a-1245e623cc52
#
#                                                  Flags  Mode  Runtime  \
# 5    ['-O0' '-funfolding-dict-discount=30' '-fmax-s...  norm    1.709
# 6    ['-O0' '-fdicts-strict' '-ffull-laziness' '-fl...  norm    1.718
# 8    ['-O0' '-fmax-worker-args=10' '-fstatic-argume...  norm    1.706
# 10   ['-O0' '-fsimplifier-phases=2' '-funbox-small-...  norm    1.781
# 11   ['-O0' '-fsimpl-tick-factor=100' '-fmax-inline...  norm    1.701
# ..                                                 ...   ...      ...
# 269  ['-O0' '-foptimal-applicative-do' '-fdicts-str...  norm    1.713
# 285  ['-O0' '-fvectorise' '-fdo-lambda-eta-expansio...  norm    1.756
# 291  ['-O0' '-fcmm-sink' '-fmax-simplifier-iteratio...  norm    1.698
# 294  ['-O0' '-fcall-arity' '-fdo-lambda-eta-expansi...  norm    1.722
# 301  ['-O0' '-fdo-eta-reduction' '-fcmm-sink' '-fun...  norm    1.706
#
#      Elapsed_Time
# 5           1.709
# 6           1.718
# 8           1.706
# 10          1.781
# 11          1.701
# ..            ...
# 269         1.713
# 285         1.756
# 291         1.698
# 294         1.722
# 301         1.706
#
# [72 rows x 5 columns]
