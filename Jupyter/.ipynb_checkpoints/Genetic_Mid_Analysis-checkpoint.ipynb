# %% [markdown]
# # Analysis of Iterative Optimization Results

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
dir_path = "files/Genetic_Mid_Display"

# TODO: Import as CSV here


tables = {}

# %% [markdown]
# ## Improvements

# %% [markdown]
# ### Normalization (Z-Score)

# %%
normalized_tables = {}
tick_labels = []

for t_name, t in tables.items():
    temp_table = t.copy()
    temp_table ["Runtime"] = (temp_table ["Runtime"] - temp_table ["Runtime"].mean())/temp_table ["Runtime"].std()
    temp_table .drop(columns=["Elapsed_Time","Mode"])
    normalized_tables[t_name] = temp_table

# %% [markdown]
# ### Normalization (-O2)

# %%
normalized_tables_o2 = {}
tick_labels_o2 = []

for t_name, t in tables.items():
    temp_table = t.copy()
    normalize_around = t[t["ID"] == "-O2"].iloc[0]["Runtime"]
    offset = normalize_around - temp_table["Runtime"].mean()
    temp_table ["Runtime"] = temp_table["Runtime"] - offset
    temp_table .drop(columns=["Elapsed_Time","Mode"])
    normalized_tables_o2[t_name] = temp_table

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Z-Score

# %%
fig, ax = plt.subplots()

lst1 = []

for t in normalized_tables.values():
    lst1.append(t["Runtime"])

ax.boxplot(lst1)
ax.set_xticklabels(normalized_tables.keys())
ax.set_ylabel("Normalized Z Runtime (s)")
ax.set_title("Distribution of Flag Sets")

plt.show()

# %% [markdown]
# ### -O2 Centered

# %%
fig, ax = plt.subplots()

lst1 = []

for t in normalized_tables_o2.values():
    lst1.append(t["Runtime"])

ax.boxplot(lst1)
ax.set_xticklabels(normalized_tables_o2.keys())
ax.set_ylabel("Normalized -O2 Runtime (s)")
ax.set_title("Distribution of Flag Sets Adjusted for -O2")

plt.show()
